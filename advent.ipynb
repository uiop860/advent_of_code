# %% [markdown]
# # Day 1: Calorie Counting

# %% [markdown]
# ## Part 1 - max calories

# %%
with open('./input_data/day_1_input.txt') as f:
  data = f.read()
data = max([sum([int(x) for x in i.split('\n')]) for i in data.split('\n\n')])
data
# Out:
# 69912

# %% [markdown]
# ## Part 2 - top 3 total calories

# %%
with open('./input_data/day_1_input.txt') as f:
  data = f.read()
data = [sum([int(x) for x in i.split('\n')]) for i in data.split('\n\n')]
data.sort()
data = sum(data[-3:])
print(data)
# Out:
# 208180
